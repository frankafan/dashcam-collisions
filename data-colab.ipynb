# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install -q kaggle

# %% [markdown]
# First upload kaggle.json into Colab files.

# %%
# !mkdir -p ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c nexar-collision-prediction -p /content/drive/MyDrive/nexcar-challenge/data/
# Out:
# ...
# 100% 29.2G/29.2G [06:44<00:00, 98.8MB/s]
# 100% 29.2G/29.2G [06:45<00:00, 77.4MB/s]

# %%
# !unzip /content/drive/MyDrive/nexcar-challenge/data/nexar-collision-prediction.zip -d /content/drive/MyDrive/nexcar-challenge/data/
# Out:
# Archive:  /content/drive/MyDrive/nexcar-challenge/data/nexar-collision-prediction.zip
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/sample_submission.csv
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/test.csv
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/test/00001.mp4
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/test/00002.mp4
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/test/00009.mp4
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/test/00011.mp4
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/test/00012.mp4
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/test/00020.mp4
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/test/00030.mp4
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/test/00033.mp4
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/test/00034.mp4
#   inflating: /content/drive/MyDrive/nexcar-challenge/data/test/00035.mp4
# ...
